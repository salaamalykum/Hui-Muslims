# %% [markdown]
# # Hui Muslims RAG Dataset Exploration
# This notebook demonstrates how to load the Parquet dataset from Hugging Face and prepare it for Retrieval-Augmented Generation (RAG) pipelines.

# %%
from datasets import load_dataset

# Load dataset from Hugging Face
dataset = load_dataset('qurancn/Hui-Muslims')
print(dataset)

# Show a sample
sample = dataset['train'][0]
print(f"Title: {sample['title']}\nLength: {sample['char_count']} chars\nURL: {sample['source_url']}")
